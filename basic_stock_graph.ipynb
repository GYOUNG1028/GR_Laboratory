# %%
#Sick!  I think this works!  Need to refine these named variables at the top.  What is really needed?
import pandas as pd
import yfinance as yf
import seaborn as sns
from yahoo_fin import stock_info as si
from pandas_datareader import data as pdr

# %%
#Establish a variable for the target stock ticker to graph
target_ticker = yf.Ticker("MSFT")

# %%
# get stock info
target_ticker.info
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 163000,
# ...

# %%
# get historical market data
hist = target_ticker.history(period="max")

# %%
# Pulls the top 5 rows of data
hist.head()
# Out:
#                 Open      High       Low     Close      Volume  Dividends  \
# Date
# 1986-03-13  0.056238  0.064508  0.056238  0.061751  1031788800        0.0
# 1986-03-14  0.061751  0.065059  0.061751  0.063956   308160000        0.0
# 1986-03-17  0.063956  0.065610  0.063956  0.065059   133171200        0.0
# 1986-03-18  0.065059  0.065610  0.062853  0.063405    67766400        0.0
# 1986-03-19  0.063405  0.063956  0.061751  0.062302    47894400        0.0
#
#             Stock Splits
# Date
# 1986-03-13           0.0
# 1986-03-14           0.0
# 1986-03-17           0.0
# 1986-03-18           0.0
# 1986-03-19           0.0

# %%
# example plotting
sns.lineplot(data=hist.loc['2021-1-1':], x='Date', y='Close');
