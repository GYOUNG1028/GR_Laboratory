# %%
#Trying to visualize USD/GBP historical rates

#Imports 
import pandas as pd
import seaborn as sns
from pandas_datareader import data as pdr

#Pull the variables from FRED.  Source site for all currencies available: https://fred.stlouisfed.org/categories/94
currency_target = pdr.DataReader('DEXUSUK','fred')

#What kind of data is being pulled?
type(currency_target)
# Out:
# pandas.core.frame.DataFrame

# %%
#Pulls the top (default 5) entries in df
currency_target.head()
# Out:
#             DEXUSUK
# DATE
# 2016-03-08   1.4225
# 2016-03-09   1.4236
# 2016-03-10   1.4306
# 2016-03-11   1.4426
# 2016-03-14   1.4324

# %%
#Graph it! If you want to change the currency above, make sure you change
#the variable in the first line as well as in the plot below (find a way to
#streamline this.)
#Also! Use this as an opportunity to work on graph manipulation (increase sizing, add labels, etc.)
sns.lineplot(data=currency_target.loc['2008-1-1':], x='DATE', y='DEXUSUK');
